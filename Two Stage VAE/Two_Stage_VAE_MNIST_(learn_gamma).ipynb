# %% [markdown]
# <a href="https://colab.research.google.com/github/TivoGatto/Thesis/blob/master/Two%20Stage%20VAE/Two_Stage_VAE_MNIST_(learn_gamma).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LIBRARIES
import numpy as np
import matplotlib.pyplot as plt

from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization, ReLU, Dense, Flatten, Reshape, Conv2DTranspose, Lambda, Concatenate
from keras.datasets import mnist
import keras.backend as K
from keras.callbacks import Callback

from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %%
# Parameters
input_dim = (32, 32, 1)
latent_dim = 16

epochs = 150
batch_size = 100

initial_lr = 1e-4
halve_at_epoch = 100

beta = 0.2

TRAIN = False
SECOND_TRAIN = True

# %%
# Functions
def vae_loss(z_mean, z_log_var):
    def loss(x_true, x_pred):
        x_true = K.reshape(x_true, (-1, np.prod(input_dim)))
        x_pred = K.reshape(x_pred, (-1, np.prod(input_dim)))

        L_rec = 0.5 * K.sum(K.square(x_true - x_pred), axis=-1)
        L_KL = 0.5 * K.sum(K.square(z_mean) + K.exp(z_log_var) - 1 - z_log_var, axis=-1)

        return K.mean(L_rec + beta * L_KL)
    return loss

def recon(x_true, x_pred):
    x_true = K.reshape(x_true, (-1, np.prod(input_dim)))
    x_pred = K.reshape(x_pred, (-1, np.prod(input_dim)))

    return K.mean(0.5 * K.sum(K.square(x_true - x_pred), axis=-1))

def KL(z_mean, z_log_var):
    def kl(x_true, x_pred):
        return K.mean(0.5 * K.sum(K.square(z_mean) + K.exp(z_log_var) - 1 - z_log_var, axis=-1))
    return kl

def sampling(args):
    z_mean, z_log_var = args
    eps = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim))

    return z_mean + K.exp(0.5 * z_log_var) * eps

def pad(x, d):
    size = x.shape[0]
    h, w = x.shape[1:]

    x = np.reshape(x, (size, h, w, 1))

    x_padded = np.zeros(shape=(size, ) + d)
    x_padded[:, :h, :w] = x

    return x_padded

class UpdateBeta(Callback):
    def on_epoch_end(self, epoch, logs):
        global beta
        val = logs['recon']
        beta = val * latent_dim / np.prod(input_dim)

        print(' - Beta = ' + str(beta))

# %%
# Dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = pad(x_train, input_dim) / 255 # For MNIST, we pad x_train and x_test in 
x_test  = pad(x_test, input_dim) / 255 # shape (32, 32, 1)

x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')

print('x_train shape: ' + str(x_train.shape))
print('x_test shape: ' + str(x_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 32, 32, 1)
# x_test shape: (10000, 32, 32, 1)

# %%
# First stage VAE

# ENCODER
x = Input(shape=input_dim) # Shape (32, 32, 1)

h = Conv2D(32, 4, strides=(2, 2), padding='same')(x) # Shape (16, 16, 32)
h = BatchNormalization()(h)
h = ReLU()(h)

h = Conv2D(64, 4, strides=(2, 2), padding='same')(h) # Shape (8, 8, 64)
h = BatchNormalization()(h)
h = ReLU()(h)

h = Conv2D(128, 4, strides=(2, 2), padding='same')(h) # Shape (4, 4, 128)
h = BatchNormalization()(h)
h = ReLU()(h)

h = Flatten()(h)

z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)
z = Lambda(sampling)([z_mean, z_log_var])

encoder = Model(x, [z, z_mean, z_log_var])

# DECODER
z_in = Input(shape=(latent_dim, ))

h = Dense(4 * 4 * 128)(z_in)
h = Reshape((4, 4, 128))(h)
h = BatchNormalization()(h)
h = ReLU()(h)

h = Conv2DTranspose(128, 4, strides=(2, 2), padding='same')(h) # Shape (8, 8, 128)
h = BatchNormalization()(h)
h = ReLU()(h)

h = Conv2DTranspose(64, 4, strides=(2, 2), padding='same')(h) # Shape (16, 16, 64)
h = BatchNormalization()(h)
h = ReLU()(h)

h = Conv2DTranspose(32, 4, strides=(2, 2), padding='same')(h) # Shape (32, 32, 32)
h = BatchNormalization()(h)
h = ReLU()(h)

x_decoded = Conv2DTranspose(1, 4, strides=(1, 1), padding='same', activation='sigmoid')(h) # Shape (32, 32, 1)

decoder = Model(z_in, x_decoded)

# VAE
x_recon = decoder(z)

vae = Model(x, x_recon)

# Compile model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import PiecewiseConstantDecay
steps_per_epoch = 54000 / batch_size
lr_schedule = PiecewiseConstantDecay([steps_per_epoch * halve_at_epoch], [initial_lr, initial_lr/2])
optimizer = Adam(learning_rate=lr_schedule)

vae.compile(optimizer=optimizer, loss=vae_loss(z_mean, z_log_var), metrics=[recon, KL(z_mean, z_log_var)])

# %%
total_hist = []
if TRAIN:
    for i in range(15):
        # Fit model
        vae.compile(optimizer=optimizer, loss=vae_loss(z_mean, z_log_var, beta), metrics=[recon, KL(z_mean, z_log_var)])
        hist = vae.fit(x_train, x_train, batch_size=batch_size, epochs=10, verbose=1, validation_split=0.1, callbacks=[UpdateBeta()])

        total_hist.append(hist)

# %% [markdown]
# # Save training history

# %%
if TRAIN:
    loss = []
    recon = []
    kl = []
    val_loss = []
    val_recon = []
    val_kl = []
    for hist in total_hist:
        loss += hist.history['loss']
        recon += hist.history['recon']
        kl += hist.history['kl']

        val_loss += hist.history['val_loss']
        val_recon += hist.history['val_recon']
        val_kl += hist.history['val_kl']

    loss = np.asarray(loss)
    recon = np.asarray(recon)
    kl = np.asarray(kl)
    val_loss = np.asarray(val_loss)
    val_recon = np.asarray(val_recon)
    val_kl = np.asarray(val_kl)
    from numpy import savetxt
    # save history
    data = np.asarray([loss, recon, kl, val_loss, val_recon, val_kl])
    savetxt('twostage_VAE_MNIST_learngamma.csv', data, delimiter=',')

    vae.save_weights('twostage_VAE_MNIST_learngamma.h5')
else:
    vae.load_weights('twostage_VAE_MNIST_learngamma.h5')

# %% [markdown]
# # Second stage

# %%
# Second Stage VAE

# Loss
def second_stage_loss(u_mean, u_log_var):
    def loss(x_true, x_pred):
        L_rec = 0.5 * K.sum(K.square(x_true - x_pred), axis=-1)
        L_KL = 0.5 * K.sum(K.square(u_mean) + K.exp(u_log_var) - 1 - u_log_var, axis=-1)

        return K.mean(L_rec + 0.1 * L_KL)
    return loss

def second_stage_recon(x_true, x_pred):
    return K.mean(0.5 * K.sum(K.square(x_true - x_pred), axis=-1))

def second_stage_kl(u_mean, u_log_var):
    def second_kl(x_true, x_pred):
        return K.mean(0.5 * K.sum(K.square(u_mean) + K.exp(u_log_var) - 1 - u_log_var, axis=-1))
    return second_kl

def second_stage_sampling(args):
    u_mean, u_log_var = args
    eps = K.random_normal(shape=(batch_size, latent_dim))

    return u_mean + eps * K.exp(0.5 * u_log_var)

# Encoder
intermediate_dim = 1024

z = Input(shape=(latent_dim, ))

h = Dense(intermediate_dim, activation='relu')(z)
h = Dense(intermediate_dim, activation='relu')(h)
h = Dense(intermediate_dim, activation='relu')(h)

h = Concatenate()([h, z])

u_mean = Dense(latent_dim)(h)
u_log_var = Dense(latent_dim)(h)

u = Lambda(second_stage_sampling)([u_mean, u_log_var])
second_encoder = Model(z, [u, u_mean, u_log_var])

# Decoder
u_in = Input(shape=(latent_dim, ))

h = Dense(intermediate_dim, activation='relu')(u_in)
h = Dense(intermediate_dim, activation='relu')(h)
h = Dense(intermediate_dim, activation='relu')(h)

h = Concatenate()([h, u_in])

z_decoded = Dense(latent_dim)(h)
second_decoder = Model(u_in, z_decoded)

# VAE
z_reconstructed = second_decoder(u)
second_vae = Model(z, z_reconstructed)

# Compile model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import PiecewiseConstantDecay
steps_per_epoch = 60000 / batch_size
lr_schedule = PiecewiseConstantDecay([steps_per_epoch * halve_at_epoch], [initial_lr, initial_lr/2])
optimizer = Adam(learning_rate=lr_schedule)
second_vae.compile(optimizer=optimizer, loss=second_stage_loss(u_mean, u_log_var), metrics=[second_stage_recon, second_stage_kl(u_mean, u_log_var)])

# %%
# Generate second stage Dataset
z_train = encoder.predict(x_train)[0]
z_test = encoder.predict(x_test)[0]
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_v1.py:2070: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.

# %%
if SECOND_TRAIN:
    # Fit second stage VAE
    second_vae.fit(z_train, z_train, batch_size=batch_size, epochs=epochs, verbose=1)
    
    second_vae.save_weights('second_twostage_VAE_MNIST_learngamma.h5')
else:
    second_vae.load_weights('second_twostage_VAE_MNIST_learngamma.h5')
# Out:
# Train on 60000 samples
# Epoch 1/150
# 60000/60000 [==============================] - 2s 41us/sample - loss: 3.2584 - second_stage_recon: 1.6145 - second_kl: 16.4381
# Epoch 2/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.6437 - second_stage_recon: 0.8831 - second_kl: 17.6054
# Epoch 3/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.6154 - second_stage_recon: 0.8712 - second_kl: 17.4422
# Epoch 4/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.5988 - second_stage_recon: 0.8682 - second_kl: 17.3058
# Epoch 5/150
# 60000/60000 [==============================] - 2s 40us/sample - loss: 2.5802 - second_stage_recon: 0.8622 - second_kl: 17.1803
# Epoch 6/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.5652 - second_stage_recon: 0.8572 - second_kl: 17.0795
# Epoch 7/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.5550 - second_stage_recon: 0.8567 - second_kl: 16.9828
# Epoch 8/150
# 60000/60000 [==============================] - 2s 40us/sample - loss: 2.5471 - second_stage_recon: 0.8537 - second_kl: 16.9339
# Epoch 9/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.5397 - second_stage_recon: 0.8525 - second_kl: 16.8721
# Epoch 10/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.5300 - second_stage_recon: 0.8497 - second_kl: 16.8028
# Epoch 11/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.5222 - second_stage_recon: 0.8457 - second_kl: 16.7651
# Epoch 12/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.5148 - second_stage_recon: 0.8440 - second_kl: 16.7079
# Epoch 13/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.5073 - second_stage_recon: 0.8413 - second_kl: 16.6601
# Epoch 14/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.5038 - second_stage_recon: 0.8408 - second_kl: 16.6302
# Epoch 15/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4986 - second_stage_recon: 0.8383 - second_kl: 16.6035
# Epoch 16/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.4929 - second_stage_recon: 0.8356 - second_kl: 16.5736
# Epoch 17/150
# 60000/60000 [==============================] - 2s 40us/sample - loss: 2.4869 - second_stage_recon: 0.8340 - second_kl: 16.5294
# Epoch 18/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.4829 - second_stage_recon: 0.8319 - second_kl: 16.5099
# Epoch 19/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.4795 - second_stage_recon: 0.8308 - second_kl: 16.4870
# Epoch 20/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4769 - second_stage_recon: 0.8282 - second_kl: 16.4865
# Epoch 21/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4731 - second_stage_recon: 0.8271 - second_kl: 16.4603
# Epoch 22/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4687 - second_stage_recon: 0.8267 - second_kl: 16.4193
# Epoch 23/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4678 - second_stage_recon: 0.8246 - second_kl: 16.4323
# Epoch 24/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4628 - second_stage_recon: 0.8225 - second_kl: 16.4023
# Epoch 25/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4628 - second_stage_recon: 0.8210 - second_kl: 16.4176
# Epoch 26/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4611 - second_stage_recon: 0.8216 - second_kl: 16.3948
# Epoch 27/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.4583 - second_stage_recon: 0.8206 - second_kl: 16.3776
# Epoch 28/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4537 - second_stage_recon: 0.8173 - second_kl: 16.3642
# Epoch 29/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4516 - second_stage_recon: 0.8161 - second_kl: 16.3555
# Epoch 30/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4510 - second_stage_recon: 0.8173 - second_kl: 16.3369
# Epoch 31/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.4486 - second_stage_recon: 0.8144 - second_kl: 16.3425
# Epoch 32/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4465 - second_stage_recon: 0.8141 - second_kl: 16.3243
# Epoch 33/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4433 - second_stage_recon: 0.8141 - second_kl: 16.2921
# Epoch 34/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4443 - second_stage_recon: 0.8125 - second_kl: 16.3181
# Epoch 35/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4401 - second_stage_recon: 0.8114 - second_kl: 16.2865
# Epoch 36/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4404 - second_stage_recon: 0.8109 - second_kl: 16.2946
# Epoch 37/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4366 - second_stage_recon: 0.8094 - second_kl: 16.2724
# Epoch 38/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4367 - second_stage_recon: 0.8093 - second_kl: 16.2743
# Epoch 39/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4357 - second_stage_recon: 0.8091 - second_kl: 16.2660
# Epoch 40/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4334 - second_stage_recon: 0.8061 - second_kl: 16.2722
# Epoch 41/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4314 - second_stage_recon: 0.8071 - second_kl: 16.2436
# Epoch 42/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.4322 - second_stage_recon: 0.8064 - second_kl: 16.2579
# Epoch 43/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4282 - second_stage_recon: 0.8047 - second_kl: 16.2349
# Epoch 44/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.4268 - second_stage_recon: 0.8036 - second_kl: 16.2322
# Epoch 45/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4256 - second_stage_recon: 0.8039 - second_kl: 16.2167
# Epoch 46/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.4252 - second_stage_recon: 0.8021 - second_kl: 16.2309
# Epoch 47/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4229 - second_stage_recon: 0.8028 - second_kl: 16.2012
# Epoch 48/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4222 - second_stage_recon: 0.8017 - second_kl: 16.2052
# Epoch 49/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4212 - second_stage_recon: 0.8004 - second_kl: 16.2083
# Epoch 50/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4195 - second_stage_recon: 0.8002 - second_kl: 16.1927
# Epoch 51/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4190 - second_stage_recon: 0.7996 - second_kl: 16.1934
# Epoch 52/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4176 - second_stage_recon: 0.7994 - second_kl: 16.1827
# Epoch 53/150
# 60000/60000 [==============================] - 2s 40us/sample - loss: 2.4192 - second_stage_recon: 0.7980 - second_kl: 16.2118
# Epoch 54/150
# 60000/60000 [==============================] - 2s 40us/sample - loss: 2.4172 - second_stage_recon: 0.7975 - second_kl: 16.1978
# Epoch 55/150
# 60000/60000 [==============================] - 2s 40us/sample - loss: 2.4164 - second_stage_recon: 0.7981 - second_kl: 16.1823
# Epoch 56/150
# 60000/60000 [==============================] - 2s 40us/sample - loss: 2.4127 - second_stage_recon: 0.7973 - second_kl: 16.1534
# Epoch 57/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.4115 - second_stage_recon: 0.7960 - second_kl: 16.1546
# Epoch 58/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4111 - second_stage_recon: 0.7970 - second_kl: 16.1410
# Epoch 59/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4092 - second_stage_recon: 0.7958 - second_kl: 16.1334
# Epoch 60/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4103 - second_stage_recon: 0.7949 - second_kl: 16.1540
# Epoch 61/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 2.4072 - second_stage_recon: 0.7935 - second_kl: 16.1370
# Epoch 62/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4056 - second_stage_recon: 0.7931 - second_kl: 16.1255
# Epoch 63/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4069 - second_stage_recon: 0.7929 - second_kl: 16.1398
# Epoch 64/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4082 - second_stage_recon: 0.7926 - second_kl: 16.1566
# Epoch 65/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4073 - second_stage_recon: 0.7914 - second_kl: 16.1587
# Epoch 66/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4040 - second_stage_recon: 0.7906 - second_kl: 16.1342
# Epoch 67/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4024 - second_stage_recon: 0.7900 - second_kl: 16.1245
# Epoch 68/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.4023 - second_stage_recon: 0.7898 - second_kl: 16.1251
# Epoch 69/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3993 - second_stage_recon: 0.7899 - second_kl: 16.0939
# Epoch 70/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3989 - second_stage_recon: 0.7891 - second_kl: 16.0979
# Epoch 71/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3991 - second_stage_recon: 0.7894 - second_kl: 16.0968
# Epoch 72/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 2.3959 - second_stage_recon: 0.7878 - second_kl: 16.0813
# Epoch 73/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3953 - second_stage_recon: 0.7873 - second_kl: 16.0805
# Epoch 74/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3954 - second_stage_recon: 0.7869 - second_kl: 16.0851
# Epoch 75/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3969 - second_stage_recon: 0.7877 - second_kl: 16.0923
# Epoch 76/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3965 - second_stage_recon: 0.7860 - second_kl: 16.1050
# Epoch 77/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3935 - second_stage_recon: 0.7856 - second_kl: 16.0791
# Epoch 78/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3949 - second_stage_recon: 0.7863 - second_kl: 16.0855
# Epoch 79/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.3934 - second_stage_recon: 0.7854 - second_kl: 16.0798
# Epoch 80/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3916 - second_stage_recon: 0.7854 - second_kl: 16.0621
# Epoch 81/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3918 - second_stage_recon: 0.7849 - second_kl: 16.0696
# Epoch 82/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3908 - second_stage_recon: 0.7843 - second_kl: 16.0651
# Epoch 83/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3912 - second_stage_recon: 0.7836 - second_kl: 16.0757
# Epoch 84/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3899 - second_stage_recon: 0.7836 - second_kl: 16.0635
# Epoch 85/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3891 - second_stage_recon: 0.7823 - second_kl: 16.0681
# Epoch 86/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3864 - second_stage_recon: 0.7830 - second_kl: 16.0339
# Epoch 87/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3871 - second_stage_recon: 0.7831 - second_kl: 16.0396
# Epoch 88/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3882 - second_stage_recon: 0.7827 - second_kl: 16.0550
# Epoch 89/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 2.3854 - second_stage_recon: 0.7821 - second_kl: 16.0335
# Epoch 90/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3838 - second_stage_recon: 0.7815 - second_kl: 16.0222
# Epoch 91/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3863 - second_stage_recon: 0.7810 - second_kl: 16.0530
# Epoch 92/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3851 - second_stage_recon: 0.7813 - second_kl: 16.0376
# Epoch 93/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3836 - second_stage_recon: 0.7806 - second_kl: 16.0302
# Epoch 94/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3817 - second_stage_recon: 0.7814 - second_kl: 16.0025
# Epoch 95/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3800 - second_stage_recon: 0.7804 - second_kl: 15.9967
# Epoch 96/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3809 - second_stage_recon: 0.7775 - second_kl: 16.0336
# Epoch 97/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3828 - second_stage_recon: 0.7786 - second_kl: 16.0425
# Epoch 98/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 2.3838 - second_stage_recon: 0.7790 - second_kl: 16.0483
# Epoch 99/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3810 - second_stage_recon: 0.7776 - second_kl: 16.0341
# Epoch 100/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3784 - second_stage_recon: 0.7776 - second_kl: 16.0081
# Epoch 101/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3658 - second_stage_recon: 0.7649 - second_kl: 16.0089
# Epoch 102/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3633 - second_stage_recon: 0.7635 - second_kl: 15.9983
# Epoch 103/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3630 - second_stage_recon: 0.7639 - second_kl: 15.9911
# Epoch 104/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3616 - second_stage_recon: 0.7613 - second_kl: 16.0024
# Epoch 105/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.3633 - second_stage_recon: 0.7612 - second_kl: 16.0214
# Epoch 106/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3621 - second_stage_recon: 0.7620 - second_kl: 16.0014
# Epoch 107/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3592 - second_stage_recon: 0.7614 - second_kl: 15.9781
# Epoch 108/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3609 - second_stage_recon: 0.7605 - second_kl: 16.0039
# Epoch 109/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3582 - second_stage_recon: 0.7604 - second_kl: 15.9787
# Epoch 110/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.3582 - second_stage_recon: 0.7620 - second_kl: 15.9612
# Epoch 111/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3569 - second_stage_recon: 0.7600 - second_kl: 15.9691
# Epoch 112/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3584 - second_stage_recon: 0.7617 - second_kl: 15.9674
# Epoch 113/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.3552 - second_stage_recon: 0.7610 - second_kl: 15.9421
# Epoch 114/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.3590 - second_stage_recon: 0.7599 - second_kl: 15.9910
# Epoch 115/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3559 - second_stage_recon: 0.7594 - second_kl: 15.9650
# Epoch 116/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3564 - second_stage_recon: 0.7584 - second_kl: 15.9800
# Epoch 117/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.3563 - second_stage_recon: 0.7590 - second_kl: 15.9728
# Epoch 118/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3585 - second_stage_recon: 0.7599 - second_kl: 15.9861
# Epoch 119/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.3564 - second_stage_recon: 0.7592 - second_kl: 15.9721
# Epoch 120/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.3573 - second_stage_recon: 0.7589 - second_kl: 15.9847
# Epoch 121/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3561 - second_stage_recon: 0.7593 - second_kl: 15.9677
# Epoch 122/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3580 - second_stage_recon: 0.7591 - second_kl: 15.9889
# Epoch 123/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3539 - second_stage_recon: 0.7570 - second_kl: 15.9688
# Epoch 124/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.3523 - second_stage_recon: 0.7585 - second_kl: 15.9388
# Epoch 125/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3550 - second_stage_recon: 0.7570 - second_kl: 15.9805
# Epoch 126/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3538 - second_stage_recon: 0.7570 - second_kl: 15.9678
# Epoch 127/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.3541 - second_stage_recon: 0.7575 - second_kl: 15.9660
# Epoch 128/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3527 - second_stage_recon: 0.7575 - second_kl: 15.9519
# Epoch 129/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3521 - second_stage_recon: 0.7580 - second_kl: 15.9412
# Epoch 130/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3520 - second_stage_recon: 0.7575 - second_kl: 15.9456
# Epoch 131/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3497 - second_stage_recon: 0.7571 - second_kl: 15.9261
# Epoch 132/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3502 - second_stage_recon: 0.7568 - second_kl: 15.9344
# Epoch 133/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3508 - second_stage_recon: 0.7566 - second_kl: 15.9415
# Epoch 134/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3536 - second_stage_recon: 0.7575 - second_kl: 15.9610
# Epoch 135/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3521 - second_stage_recon: 0.7561 - second_kl: 15.9597
# Epoch 136/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3494 - second_stage_recon: 0.7564 - second_kl: 15.9301
# Epoch 137/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3502 - second_stage_recon: 0.7552 - second_kl: 15.9498
# Epoch 138/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3514 - second_stage_recon: 0.7563 - second_kl: 15.9514
# Epoch 139/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3524 - second_stage_recon: 0.7560 - second_kl: 15.9639
# Epoch 140/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3502 - second_stage_recon: 0.7551 - second_kl: 15.9507
# Epoch 141/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3492 - second_stage_recon: 0.7546 - second_kl: 15.9456
# Epoch 142/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3484 - second_stage_recon: 0.7543 - second_kl: 15.9406
# Epoch 143/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3474 - second_stage_recon: 0.7562 - second_kl: 15.9124
# Epoch 144/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3480 - second_stage_recon: 0.7550 - second_kl: 15.9297
# Epoch 145/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3495 - second_stage_recon: 0.7555 - second_kl: 15.9409
# Epoch 146/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3481 - second_stage_recon: 0.7549 - second_kl: 15.9313
# Epoch 147/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.3498 - second_stage_recon: 0.7541 - second_kl: 15.9574
# Epoch 148/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.3474 - second_stage_recon: 0.7541 - second_kl: 15.9326
# Epoch 149/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.3474 - second_stage_recon: 0.7543 - second_kl: 15.9306
# Epoch 150/150
# 60000/60000 [==============================] - 2s 40us/sample - loss: 2.3471 - second_stage_recon: 0.7530 - second_kl: 15.9413

# %% [markdown]
# # Generation and Reconstruction
#
# Now we have two VAE network: \\
# 1) u <- p(u) = N(0, I) \\
# 2) z <- q(z) = E_p(u)[q(z|u)] \\
# 3) x <- p(x) = E_q(z)[p(x|z)] \\
#
# And we can use them to generate new samples.

# %%
# Reconstruction

"""
Here we don't need to use the second stage VAE, 'cause we don't use q(z)
"""
n = 10
digit_size = input_dim[0]

x_recon = vae.predict(x_test, batch_size=batch_size)
x_recon = np.reshape(x_recon, (-1, digit_size, digit_size))
x_test = np.reshape(x_test, (-1, digit_size, digit_size))
figure = np.zeros((2 * digit_size, n * digit_size))

for i in range(n):
    figure[:digit_size, i * digit_size: (i+1) * digit_size] = x_test[i]
    figure[digit_size:, i * digit_size: (i+1) * digit_size] = x_recon[i]

x_test = np.reshape(x_test, (-1, ) + input_dim)

plt.style.use('default')
plt.imshow(figure, cmap='gray')
plt.savefig('twostage_VAE_MNIST_learngamma_reconstruction.png')
plt.show()

# %%
# Generation
n = 10 #figure with n x n digits
digit_size = 32
figure = np.zeros((digit_size * n, digit_size * n))
# we will sample n points randomly sampled

"""
We want to sample z from q(z) = E_p(u)[q(z|u)]
p(u) = N(0, I)
"""

u_sample = np.random.normal(size=(n**2, latent_dim), scale=1)
z_sample = second_decoder.predict(u_sample, batch_size=batch_size)
for i in range(n):
    for j in range(n):
        x_decoded = decoder.predict(np.array([z_sample[i + n * j]]))
        digit = x_decoded.reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
            j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='gray')
plt.savefig('twostage_VAE_MNIST_learngamma_generation.png')
plt.show()

# %% [markdown]
# # Interpolation

# %%
T = 10
N = 15

s = 10
k = 100

X_final = [0] * N
for n in range(N):
    x_a = x_test[n + s]
    x_b = x_test[n + k]

    z_a = encoder.predict(np.reshape(x_a, (1, 32, 32, 1)))[0]
    z_b = encoder.predict(np.reshape(x_b, (1, 32, 32, 1)))[0]


    X = [0] * T
    for i in range(T):
        t = i/T
        z = t * z_a + (1 - t) * z_b

        X[i] = decoder.predict(z)
    
    X_final[n] = X

digit_size = 32
figure = np.zeros((N * digit_size, T * digit_size))
for n in range(N):
    for i in range(T):
        figure[n * digit_size : (n+1) * digit_size, i * digit_size : (i+1) * digit_size] = X_final[n][i][0, :, :, 0]

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='gray')
plt.savefig('twostage_VAE_MNIST_learngamma_interpolation.png')
plt.show()

# %% [markdown]
# #Nearest Neighbour

# %%
# We want to investigate overfitting
def get_distance(x, y_vec):
    digit_size = x.shape[0]
    x = np.reshape(x, (digit_size**2, ))
    y_vec = np.reshape(y_vec, (-1, digit_size**2, ))

    res = np.zeros((y_vec.shape[0], ))
    for j in range(y_vec.shape[0]):
        res[j] = np.mean(np.square(x - y_vec[j]))

    return res

N = 3 # Images we need to check
digit_size = 32
u = np.random.normal(size=(N, latent_dim), scale=1)
z = second_decoder.predict(u, batch_size=batch_size)
x_gen = decoder.predict(z)
figure = np.zeros((N * digit_size, 2 * digit_size))
for i in range(N):
    x = x_gen[i]
    distances = get_distance(x, x_train)
    m = np.min(distances)
    i_m = np.argmin(distances)

    figure[i * digit_size : (i+1) * digit_size, : digit_size] = x[:, :, 0]
    figure[i * digit_size : (i+1) * digit_size, digit_size :] = x_train[i_m][:, :, 0]

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='gray')
plt.savefig('twostage_VAE_MNIST_learngamma_NN.png')
plt.show()

# %% [markdown]
# # Metrics Evaluation

# %%
import numpy as np
from scipy.linalg import sqrtm
from keras.applications.inception_v3 import InceptionV3
import tensorflow as tf
#from keras.applications.inception_v3 import preprocess_input
#from skimage.transform import resize
#from tensorflow.keras.models import load_model
#import os
#from matplotlib import pyplot

# prepare the inception v3 model
model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3), weights='imagenet')

def get_inception_activations(inps, batch_size=100):
    n_batches = inps.shape[0]//batch_size
    act = np.zeros([inps.shape[0], 2048], dtype = np.float32)
    for i in range(n_batches):
        inp = inps[i * batch_size:(i + 1) * batch_size]
        inpr = tf.image.resize(inp, (299, 299))
        act[i * batch_size:(i + 1) * batch_size] = model.predict(inpr,steps=1)
        
        print('Processed ' + str((i+1) * batch_size) + ' images.')
    return act

def get_fid(images1, images2):
    print(images1.shape)
    print(images2.shape)
    print(type(images1))
    # calculate activations
    act1 = get_inception_activations(images1,batch_size=100)
    #print(np.shape(act1))
    act2 = get_inception_activations(images2,batch_size=100)
    # compute mean and covariance statistics
    mu1, sigma1 = act1.mean(axis=0), np.cov(act1, rowvar=False)
    mu2, sigma2 = act2.mean(axis=0), np.cov(act2, rowvar=False)
    # calculate sum squared difference between means
    ssdiff = np.sum((mu1 - mu2)**2.0)
    # compute sqrt of product between cov
    covmean = sqrtm(sigma1.dot(sigma2))
    # check and correct imaginary numbers from sqrt
    if np.iscomplexobj(covmean):
        covmean = covmean.real
    # calculate score
    fid = ssdiff + np.trace(sigma1 + sigma2 - 2.0 * covmean)
    return fid

u_sample = np.random.normal(0, 1, size=(x_test.shape[0], latent_dim))
z_sample = second_decoder.predict(u_sample)
x_gen = decoder.predict(z_sample)
x_gens = np.zeros((x_test.shape[0], x_test.shape[1], x_test.shape[2], 3))
x_tests = np.zeros((x_test.shape[0], x_test.shape[1], x_test.shape[2], 3))
for i in range(3):
	x_gens[:, :, :, i] = x_gen[:, :, :, 0]
	x_tests[:, :, :, i] = x_test[:, :, :, 0]

fid = get_fid(x_tests, x_gens)
print('\n FID: %.3f' % fid)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)
# <class 'numpy.ndarray'>
# Processed 100 images.
# Processed 200 images.
# Processed 300 images.
# Processed 400 images.
# Processed 500 images.
# Processed 600 images.
# Processed 700 images.
# Processed 800 images.
# Processed 900 images.
# Processed 1000 images.
# Processed 1100 images.
# Processed 1200 images.
# Processed 1300 images.
# Processed 1400 images.
# Processed 1500 images.
# Processed 1600 images.
# Processed 1700 images.
# Processed 1800 images.
# Processed 1900 images.
# Processed 2000 images.
# Processed 2100 images.
# Processed 2200 images.
# Processed 2300 images.
# Processed 2400 images.
# Processed 2500 images.
# Processed 2600 images.
# Processed 2700 images.
# Processed 2800 images.
# Processed 2900 images.
# Processed 3000 images.
# Processed 3100 images.
# Processed 3200 images.
# Processed 3300 images.
# Processed 3400 images.
# Processed 3500 images.
# Processed 3600 images.
# Processed 3700 images.
# Processed 3800 images.
# Processed 3900 images.
# Processed 4000 images.
# Processed 4100 images.
# Processed 4200 images.
# Processed 4300 images.
# Processed 4400 images.
# Processed 4500 images.
# Processed 4600 images.
# Processed 4700 images.
# Processed 4800 images.
# Processed 4900 images.
# Processed 5000 images.
# Processed 5100 images.
# Processed 5200 images.
# Processed 5300 images.
# Processed 5400 images.
# Processed 5500 images.
# Processed 5600 images.
# Processed 5700 images.
# Processed 5800 images.
# Processed 5900 images.
# Processed 6000 images.
# Processed 6100 images.
# Processed 6200 images.
# Processed 6300 images.
# Processed 6400 images.
# Processed 6500 images.
# Processed 6600 images.
# Processed 6700 images.
# Processed 6800 images.
# Processed 6900 images.
# Processed 7000 images.
# Processed 7100 images.
# Processed 7200 images.
# Processed 7300 images.
# Processed 7400 images.
# Processed 7500 images.
# Processed 7600 images.
# Processed 7700 images.
# Processed 7800 images.
# Processed 7900 images.
# Processed 8000 images.
# Processed 8100 images.
# Processed 8200 images.
# Processed 8300 images.
# Processed 8400 images.
# Processed 8500 images.
# Processed 8600 images.
# Processed 8700 images.
# Processed 8800 images.
# Processed 8900 images.
# Processed 9000 images.
# Processed 9100 images.
# Processed 9200 images.
# Processed 9300 images.
# Processed 9400 images.
# Processed 9500 images.
# Processed 9600 images.
# Processed 9700 images.
# Processed 9800 images.
# Processed 9900 images.
# Processed 10000 images.
# Processed 100 images.
# Processed 200 images.
# Processed 300 images.
# Processed 400 images.
# Processed 500 images.
# Processed 600 images.
# Processed 700 images.
# Processed 800 images.
# Processed 900 images.
# Processed 1000 images.
# Processed 1100 images.
# Processed 1200 images.
# Processed 1300 images.
# Processed 1400 images.
# Processed 1500 images.
# Processed 1600 images.
# Processed 1700 images.
# Processed 1800 images.
# Processed 1900 images.
# Processed 2000 images.
# Processed 2100 images.
# Processed 2200 images.
# Processed 2300 images.
# Processed 2400 images.
# Processed 2500 images.
# Processed 2600 images.
# Processed 2700 images.
# Processed 2800 images.
# Processed 2900 images.
# Processed 3000 images.
# Processed 3100 images.
# Processed 3200 images.
# Processed 3300 images.
# Processed 3400 images.
# Processed 3500 images.
# Processed 3600 images.
# Processed 3700 images.
# Processed 3800 images.
# Processed 3900 images.
# Processed 4000 images.
# Processed 4100 images.
# Processed 4200 images.
# Processed 4300 images.
# Processed 4400 images.
# Processed 4500 images.
# Processed 4600 images.
# Processed 4700 images.
# Processed 4800 images.
# Processed 4900 images.
# Processed 5000 images.
# Processed 5100 images.
# Processed 5200 images.
# Processed 5300 images.
# Processed 5400 images.
# Processed 5500 images.
# Processed 5600 images.
# Processed 5700 images.
# Processed 5800 images.
# Processed 5900 images.
# Processed 6000 images.
# Processed 6100 images.
# Processed 6200 images.
# Processed 6300 images.
# Processed 6400 images.
# Processed 6500 images.
# Processed 6600 images.
# Processed 6700 images.
# Processed 6800 images.
# Processed 6900 images.
# Processed 7000 images.
# Processed 7100 images.
# Processed 7200 images.
# Processed 7300 images.
# Processed 7400 images.
# Processed 7500 images.
# Processed 7600 images.
# Processed 7700 images.
# Processed 7800 images.
# Processed 7900 images.
# Processed 8000 images.
# Processed 8100 images.
# Processed 8200 images.
# Processed 8300 images.
# Processed 8400 images.
# Processed 8500 images.
# Processed 8600 images.
# Processed 8700 images.
# Processed 8800 images.
# Processed 8900 images.
# Processed 9000 images.
# Processed 9100 images.
# Processed 9200 images.
# Processed 9300 images.
# Processed 9400 images.
# Processed 9500 images.
# Processed 9600 images.
# Processed 9700 images.
# Processed 9800 images.
# Processed 9900 images.
# Processed 10000 images.
#
#  FID: 22.335

# %% [markdown]
# ### Deactivated Latent Variables, Variance Loss and Variance Law

# %%
def count_deactivated_variables(z_var, treshold = 0.8):
    z_var = np.mean(z_var, axis=0)

    return np.sum(z_var > treshold)

def loss_variance(x_true, x_recon):
    x_true = np.reshape(x_true, (-1, np.prod(x_true.shape[1:])))
    x_recon = np.reshape(x_recon, (-1, np.prod(x_recon.shape[1:])))

    var_true = np.mean(np.var(x_true, axis=1), axis=0)
    var_recon = np.mean(np.var(x_recon, axis=1), axis=0)

    return np.abs(var_true - var_recon)

########################################################################################################################
# SHOW THE RESULTS
########################################################################################################################

_, z_mean, z_log_var = encoder.predict(x_test, batch_size=batch_size)
z_var = np.exp(z_log_var)
n_deact = count_deactivated_variables(z_var)
print('We have a total of ', latent_dim, ' latent variables. ', count_deactivated_variables(z_var), ' of them are deactivated')

var_law = np.mean(np.var(z_mean, axis=0) + np.mean(z_var, axis=0))
print('Variance law has a value of: ', var_law)

x_recon = vae.predict(x_train, batch_size=batch_size)
print('We lost ', loss_variance(x_test, x_recon), 'Variance of the original data')
# Out:
# We have a total of  16  latent variables.  0  of them are deactivated
# Variance law has a value of:  1.0155514
# We lost  0.0048079565 Variance of the original data

# %% [markdown]
# ### Latent space matching

# %%
# We want to verify if q(z) = p(z).

# Moments Matching
# Generate samples from q(z) and for p(z)
# p(z) = N(0, I)
# q(z) = E_q(x)[q(z|x)]
#
# For every moment we compare the moments
n = len(x_test)

u_samples = np.random.normal(size=(n, latent_dim))
p_samples = second_decoder.predict(u_samples)
q_samples = encoder.predict(x_test, batch_size=batch_size)[0]


from scipy.stats import moment
# First moment matching:
p_first_moment = np.mean(np.mean(p_samples, axis=0))
q_first_moment = np.mean(np.mean(q_samples, axis=0))

print("\n")
print("First moment of p(z): " + str(p_first_moment))
print("First moment of q(z): " + str(q_first_moment))
print("\n")

# Second moment matching:
p_second_moment = np.mean(np.var(p_samples, axis=0))
q_second_moment = np.mean(np.var(q_samples, axis=0))

print("\n")
print("Second moment of p(z): " + str(p_second_moment))
print("Second moment of q(z): " + str(q_second_moment))
print("\n")

# Thid moment matching:
p_third_moment = np.mean(moment(p_samples, moment=3, axis=0))
q_third_moment = np.mean(moment(q_samples, moment=3, axis=0))

print("\n")
print("Third moment of p(z): " + str(p_third_moment))
print("Third moment of q(z): " + str(q_third_moment))
print("\n")
# Out:
# First moment of p(z): 0.009210345
# First moment of q(z): -0.005060385
#
#
#
#
# Second moment of p(z): 0.8292612
# Second moment of q(z): 1.0151335
#
#
#
#
# Third moment of p(z): -0.010418403
# Third moment of q(z): -0.010432367

# %% [markdown]
# # MMD

# %%
# To verify that q(z) = p(z) we can also use MMD

def compute_kernel(x, y):
    return np.exp(-np.mean(np.square(x - y), axis=-1))

def compute_mmd(x, y):
    x_kernel = compute_kernel(x, x)
    y_kernel = compute_kernel(y, y)
    xy_kernel = compute_kernel(x, y)

    return np.mean(x_kernel) + np.mean(y_kernel) - 2 * np.mean(xy_kernel) 

u_samples = np.random.normal(size=(len(x_test), latent_dim))
z_p = second_decoder.predict(u_samples) # sample from p(z)
z_q = encoder.predict(x_test, batch_size=batch_size)[0]  # sample from q(z)

z_p = z_p.astype('float32')
z_q = z_q.astype('float32')

mmd = compute_mmd(z_p, z_q)
print('MMD between p(z) and q(z) is ' + str(mmd))
# Out:
# MMD between p(z) and q(z) is 1.6160348057746887
